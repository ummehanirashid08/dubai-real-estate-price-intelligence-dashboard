# %%
# Save a sample preview for quick inspection

sample_path = EXTERNAL_DATA_DIR / "raw_transactions_sample.csv"
df.head(100).to_csv(sample_path, index=False)

print("Sample file saved to:", sample_path)
# Out:
# Sample file saved to: c:\Projects\dubai-real-estate-price-intelligence-dashboard\data\external\raw_transactions_sample.csv

# %%
# Save initial data dictionary

output_path = EXTERNAL_DATA_DIR / "initial_data_dictionary.csv"
data_dictionary.to_csv(output_path, index=False)

print("Initial data dictionary saved to:", output_path)
# Out:
# Initial data dictionary saved to: c:\Projects\dubai-real-estate-price-intelligence-dashboard\data\external\initial_data_dictionary.csv

# %%
# Create initial data dictionary

data_dictionary = pd.DataFrame({
    "column_name": df.columns,
    "data_type": df.dtypes.astype(str).values,
    "missing_values": df.isnull().sum().values,
    "missing_percentage": (df.isnull().sum().values / len(df) * 100).round(2),
    "unique_values": df.nunique().values
})

data_dictionary
# Out:
#              column_name data_type  missing_values  missing_percentage  \
# 0         transaction_id       str               0                0.00
# 1           procedure_id     int64               0                0.00
# 2         trans_group_id     int64               0                0.00
# 3         trans_group_ar       str               0                0.00
# 4         trans_group_en       str               0                0.00
# 5      procedure_name_ar       str               0                0.00
# 6      procedure_name_en       str               0                0.00
# 7          instance_date       str               5                0.00
# 8       property_type_id     int64               0                0.00
# 9       property_type_ar       str               0                0.00
# 10      property_type_en       str               0                0.00
# 11  property_sub_type_id   float64          240146               22.92
# ...

# %%
# Numerical columns summary

df.describe().T
# Out:
#                             count         mean          std       min  \
# procedure_id         1,047,965.00        58.70        91.11      4.00
# trans_group_id       1,047,965.00         1.28         0.52      1.00
# property_type_id     1,047,965.00         3.02         0.73      1.00
# property_sub_type_id   807,819.00        53.90        20.64      2.00
# reg_type_id          1,047,965.00         0.71         0.46      0.00
# area_id              1,047,965.00       408.37        70.36    229.00
# project_number         657,372.00     1,281.81       703.10 -2,480.00
# has_parking          1,047,965.00         0.60         0.49      0.00
# procedure_area       1,047,965.00     1,599.63   355,851.27      0.05
# actual_worth         1,044,160.00 2,557,483.16 5,968,448.31      1.00
# meter_sale_price     1,047,965.00    13,488.75   124,693.60      0.00
# rent_value              34,299.00 1,416,090.02 1,733,329.11      2.00
# ...

# %%
# Duplicate records check

duplicate_count = df.duplicated().sum()

print("Duplicate rows:", duplicate_count)
print("Duplicate percentage:", round((duplicate_count / len(df)) * 100, 2), "%")
# Out:
# Duplicate rows: 0
# Duplicate percentage: 0.0 %

# %%
# Missing values summary

missing_summary = pd.DataFrame({
    "missing_count": df.isnull().sum(),
    "missing_percentage": (df.isnull().sum() / len(df) * 100).round(2)
}).sort_values(by="missing_percentage", ascending=False)

missing_summary
# Out:
#                       missing_count  missing_percentage
# meter_rent_price            1013663               96.73
# rent_value                  1013666               96.73
# project_name_en              390593               37.27
# project_number               390593               37.27
# project_name_ar              390593               37.27
# building_name_ar             328165               31.31
# building_name_en             326895               31.19
# rooms_en                     248935               23.75
# rooms_ar                     248935               23.75
# nearest_mall_ar              242142               23.11
# nearest_mall_en              242142               23.11
# property_sub_type_id         240146               22.92
# property_sub_type_en         240146               22.92
# property_sub_type_ar         240146               22.92
# nearest_metro_en             236824               22.60
# nearest_metro_ar             236824               22.60
# ...

# %%
# Define project paths

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()

RAW_DATA_DIR = PROJECT_ROOT / "data" / "raw"
PROCESSED_DATA_DIR = PROJECT_ROOT / "data" / "processed"
EXTERNAL_DATA_DIR = PROJECT_ROOT / "data" / "external"

print("Project root:", PROJECT_ROOT)
print("Raw data folder:", RAW_DATA_DIR)
print("Processed data folder:", PROCESSED_DATA_DIR)
print("External data folder:", EXTERNAL_DATA_DIR)
# Out:
# Project root: c:\Projects\dubai-real-estate-price-intelligence-dashboard
# Raw data folder: c:\Projects\dubai-real-estate-price-intelligence-dashboard\data\raw
# Processed data folder: c:\Projects\dubai-real-estate-price-intelligence-dashboard\data\processed
# External data folder: c:\Projects\dubai-real-estate-price-intelligence-dashboard\data\external

# %%
# Check available files in raw data folder

raw_files = list(RAW_DATA_DIR.glob("*"))

print("Files found in data/raw:")
for file in raw_files:
    print("-", file.name)
# Out:
# Files found in data/raw:
# - Transactions.csv

# %%
# Basic dataset information

print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])

print("\nColumn names:")
for col in df.columns:
    print("-", col)
# Out:
# Number of rows: 1047965
# Number of columns: 46
#
# Column names:
# - transaction_id
# - procedure_id
# - trans_group_id
# - trans_group_ar
# - trans_group_en
# - procedure_name_ar
# - procedure_name_en
# - instance_date
# - property_type_id
# - property_type_ar
# - property_type_en
# - property_sub_type_id
# - property_sub_type_ar
# - property_sub_type_en
# - property_usage_ar
# - property_usage_en
# - reg_type_id
# - reg_type_ar
# - reg_type_en
# - area_id
# - area_name_ar
# - area_name_en
# - building_name_ar
# - building_name_en
# - project_number
# - project_name_ar
# - project_name_en
# - master_project_en
# - master_project_ar
# - nearest_landmark_ar
# - nearest_landmark_en
# - nearest_metro_ar
# - nearest_metro_en
# - nearest_mall_ar
# - nearest_mall_en
# - rooms_ar
# - rooms_en
# - has_parking
# - procedure_area
# - actual_worth
# - meter_sale_price
# - rent_value
# - meter_rent_price
# - no_of_parties_role_1
# - no_of_parties_role_2
# - no_of_parties_role_3

# %%
# Load raw transactions dataset

file_path = RAW_DATA_DIR / "Transactions.csv"

try:
    df = pd.read_csv(file_path, low_memory=False)
    print("Dataset loaded successfully using default encoding.")
except UnicodeDecodeError:
    df = pd.read_csv(file_path, encoding="latin1", low_memory=False)
    print("Dataset loaded successfully using latin1 encoding.")

print("Shape of dataset:", df.shape)

df.head()
# Out:
# Dataset loaded successfully using default encoding.
# Shape of dataset: (1047965, 46)
#   transaction_id  procedure_id  trans_group_id trans_group_ar trans_group_en  \
# 0  1-11-2001-165            11               1        مبايعات          Sales
# 1   3-9-2004-223             9               3           هبات          Gifts
# 2  2-13-1996-119            13               2           رهون      Mortgages
# 3  2-14-2005-222            14               2           رهون      Mortgages
# 4   3-9-2012-874             9               3           هبات          Gifts
#
#   procedure_name_ar      procedure_name_en instance_date  property_type_id  \
# 0               بيع                   Sell    24-02-2001                 1
# 1               هبه                  Grant    13-12-2004                 4
# 2         تسجيل رهن  Mortgage Registration    12-03-2001                 1
# 3         تعديل رهن        Modify Mortgage    20-09-2005                 2
# ...

# %%
# Data types overview

df.dtypes
# Out:
# transaction_id              str
# procedure_id              int64
# trans_group_id            int64
# trans_group_ar              str
# trans_group_en              str
# procedure_name_ar           str
# procedure_name_en           str
# instance_date               str
# property_type_id          int64
# property_type_ar            str
# property_type_en            str
# property_sub_type_id    float64
# property_sub_type_ar        str
# property_sub_type_en        str
# property_usage_ar           str
# property_usage_en           str
# reg_type_id               int64
# reg_type_ar                 str
# reg_type_en                 str
# area_id                   int64
# area_name_ar                str
# area_name_en                str
# building_name_ar            str
# building_name_en            str
# project_number          float64
# project_name_ar             str
# project_name_en             str
# master_project_en           str
# master_project_ar           str
# ...

# %%
# Dubai Real Estate Price Intelligence Dashboard
# Notebook 01: Data Collection & Initial Inspection

import pandas as pd
import numpy as np
from pathlib import Path

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)
pd.set_option("display.float_format", "{:,.2f}".format)

print("Libraries imported successfully.")
# Out:
# Libraries imported successfully.
